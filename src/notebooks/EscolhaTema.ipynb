# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

# %%
def gpt_req(prompt:str):

    load_dotenv(dotenv_path='../.env')
    OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

    client = OpenAI(api_key=OPENAI_API_KEY )

    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "Você é um mestre de RPG que deverá criar uma história com base no tema escolhido pelo jogador."},
            {"role": "user", "content": prompt}
        ],
        )
    
    return completion.choices[0].message.content

# %%
tema = """Apocalipse Zombie"""

# %%
def criar_historia(tema):
    prompt_historia = f"""

    Você é um mestre de um rpg do tema {tema}

    1. A sua função é criar uma história com o tema.
    2. Me retornar uma ficha de criação de personagem com opções relacionadas ao tema.
    
    """

    resposta = gpt_req(prompt=prompt_historia)

    return resposta

# %%
print(criar_historia(tema))
# Out:
# **História do RPG: "Caminhos Sombrio"**
#
# Em um mundo devastado por um surto de zumbis, a civilização entrou em colapso. As cidades são imagens de um passado distante, agora dominadas por hordas de mortos-vivos. Aqueles que conseguiram sobreviver se dividem em grupos e facções, lutando não apenas contra os zumbis, mas também uns contra os outros pela escassez de recursos.
#
# O cenário é uma pequena cidade chamada Eldridge Falls, cercada por florestas densas e montanhas. Os sobreviventes estão tentando reunir suprimentos e informações sobre um suposto abrigo seguro conhecido como "Refúgio de Aurora", mas a jornada até lá está repleta de perigos. Rumores falam de uma facção que acaba de se estabelecer nas proximidades, se aproveitando da fraqueza dos sobreviventes e se tornando extremamente hostil.
#
# ...
